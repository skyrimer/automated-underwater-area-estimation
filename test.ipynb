# %%
from automated_underwater_area_estimation.segmentation_corals.reefsupport.model import ReefSupportModel
from automated_underwater_area_estimation.segmentation_corals.epfl.model import EPFLModel
from automated_underwater_area_estimation.segmentation_corals.segmentation_dataset import CoralSegmentationDataset
from automated_underwater_area_estimation.segmentation_corals.utils import plot_segmentation_results
from automated_underwater_area_estimation.segmentation_corals.evaluation_metrics import compute_segmentation_metrics

# %%
all_models = []
for model_name in ["yolov8_sm_latest.pt", "yolov8_xlarge_latest.pt"]:
    all_models.append(ReefSupportModel(model_name))

for model_name in ["EPFL-ECEO/segformer-b2-finetuned-coralscapes-1024-1024", "EPFL-ECEO/segformer-b5-finetuned-coralscapes-1024-1024"]:
    all_models.append(EPFLModel(model_name))
# Out:
# ...
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
dataset = CoralSegmentationDataset("./automated_underwater_area_estimation/data_preprocessed/coralscop/test")

# %%
idx = 5
ds_image, ds_golden = dataset[idx]
for model in all_models:
    print(model)
    output = model.segment_image(ds_image, False)
    plot_segmentation_results(*output, "model")
    print(compute_segmentation_metrics(output[1], ds_golden, model.device))
# Out:
# ReefSupportModel(model_name=yolov8_sm_latest.pt)
#
# 0: 704x1024 15 hard_corals, 1 soft_coral, 26.0ms
# Speed: 3.3ms preprocess, 26.0ms inference, 6.4ms postprocess per image at shape (1, 3, 704, 1024)
# {'dice': 0.7518490552902222, 'iou': 0.6023703217506409, 'precision': 0.630658745765686, 'recall': 0.9306959509849548, 'pixel_accuracy': 0.9254069924354553}
# ReefSupportModel(model_name=yolov8_xlarge_latest.pt)
#
# 0: 704x1024 10 hard_corals, 171.8ms
# Speed: 3.7ms preprocess, 171.8ms inference, 1248.7ms postprocess per image at shape (1, 3, 704, 1024)
# {'dice': 0.7731689214706421, 'iou': 0.6302163004875183, 'precision': 0.7012856602668762, 'recall': 0.8614715933799744, 'pixel_accuracy': 0.9386274218559265}
# EPFLModel(model_name=EPFL-ECEO/segformer-b2-finetuned-coralscapes-1024-1024)
# {'dice': 0.922863781452179, 'iou': 0.8567753434181213, 'precision': 0.9293968677520752, 'recall': 0.9164218306541443, 'pixel_accuracy': 0.981399655342102}
# ...

# %%
plot_segmentation_results(*dataset[idx], "Ground Truth")

# %%
from automated_underwater_area_estimation.segmentation_corals.reefsupport.model import ReefSupportModel
from automated_underwater_area_estimation.segmentation_corals.epfl.model import EPFLModel
from automated_underwater_area_estimation.segmentation_corals.segmentation_dataset import CoralSegmentationDataset
from automated_underwater_area_estimation.segmentation_corals.utils import plot_segmentation_results
from automated_underwater_area_estimation.segmentation_corals.evaluation_metrics import compute_segmentation_metrics

# %%
reef_model = ReefSupportModel("yolov8_sm_latest.pt")

# %%
dataset = CoralSegmentationDataset("./automated_underwater_area_estimation/data_preprocessed/coralscop/test")

# %%
idx = 528
ds_image, ds_golden = dataset[idx]
output = reef_model.segment_image(ds_image, True, False)
# plot_segmentation_results(*output, "model")
# print(compute_segmentation_metrics(output[1], ds_golden, model.device))
# Out:
# 0: 1024x1024 1 hard_coral, 38.6ms
# Speed: 24.7ms preprocess, 38.6ms inference, 13.2ms postprocess per image at shape (1, 3, 1024, 1024)

# %%
plot_segmentation_results(*output)

# %%
plot_segmentation_results(ds_image, ds_golden)

# %%
from torch.nn import functional as F
F.interpolate(
            ds_golden.unsqueeze(0).unsqueeze(0).float(),  # Add batch and channel dims, convert to float
                    size=(200, 500),  # Note: interpolate expects (height, width)
                    mode='nearest'
                ).squeeze().bool()
# Out:
# tensor([[False, False, False,  ..., False, False, False],
#         [False, False, False,  ..., False, False, False],
#         [False, False, False,  ..., False, False, False],
#         ...,
#         [False, False, False,  ..., False, False, False],
#         [False, False, False,  ..., False, False, False],
#         [False, False, False,  ..., False, False, False]])

# %%
ds_golden
# Out:
# tensor([[False, False, False,  ..., False, False, False],
#         [False, False, False,  ..., False, False, False],
#         [False, False, False,  ..., False, False, False],
#         ...,
#         [False, False, False,  ..., False, False, False],
#         [False, False, False,  ..., False, False, False],
#         [False, False, False,  ..., False, False, False]])

# %%
reef_model.ideal_size
# Out:
# (1024, 1024)

# %%
import json
import matplotlib.pyplot as plt
import numpy as np

# Load the data from the JSON file
with open('./automated_underwater_area_estimation/evaluation_results_vm/coralscop_train/comparison/model_comparison.json', 'r') as f:
    data = json.load(f)

# Extract model names
models = [item['model'] for item in data]
model_labels = ['ReefSupport YOLOv8 Small', 'ReefSupport YOLOv8 XLarge', 'EPFL B2', 'EPFL B5']

# Extract metrics (convert to percentage for 0-100 scale)
metrics = ['dice', 'iou', 'precision', 'recall', 'pixel_accuracy']
metric_labels = ['Dice', 'IoU', 'Precision', 'Recall', 'Pixel Accuracy']

# Prepare data arrays organized by metrics
metric_means = []
metric_stds = []

for metric in metrics:
    means_for_metric = [item[f'{metric}_mean'] * 100 for item in data]  # Convert to percentage
    stds_for_metric = [item[f'{metric}_std'] * 100 for item in data]    # Convert to percentage
    metric_means.append(means_for_metric)
    metric_stds.append(stds_for_metric)

# Set up the plot
fig, ax = plt.subplots(figsize=(14, 8))

# Set up bar positions
x = np.arange(len(metrics))  # Now x-axis represents metrics
width = 0.2  # Width of each bar
colors = ['#FF6B6B', '#4ECDC4', '#45B7D1', '#96CEB4']

# Create bars for each model
bars = []
for i, model in enumerate(models):
    # Get means and stds for this model across all metrics
    model_means = [metric_means[j][i] for j in range(len(metrics))]
    model_stds = [metric_stds[j][i] for j in range(len(metrics))]

    positions = x + (i - 1.5) * width  # Center the bars
    bars.append(ax.bar(positions, model_means, width,
                      label=model_labels[i], color=colors[i], alpha=0.8,
                      yerr=model_stds, capsize=3))

# Customize the plot
ax.set_xlabel('Metrics', fontsize=12, fontweight='bold')
ax.set_ylabel('Metric Value (%)', fontsize=12, fontweight='bold')
ax.set_title('Model Performance Comparison\nMean Metrics with Standard Deviations',
             fontsize=14, fontweight='bold', pad=20)
ax.set_xticks(x)
ax.set_xticklabels(metric_labels)
ax.set_ylim(0, 110)
ax.legend(loc='upper left', bbox_to_anchor=(1, 1))
ax.grid(True, alpha=0.3, axis='y')

# Add value labels on top of bars
for model_bars, model_idx in zip(bars, range(len(models))):
    for i, bar in enumerate(model_bars):
        height = bar.get_height()
        std_val = metric_stds[i][model_idx]
        mean_val = metric_means[i][model_idx]
        # ax.text(bar.get_x() + bar.get_width()/2., height + std_val + 1,
        #         f'{mean_val:.1f}', ha='center', va='bottom', fontsize=8)

# Adjust layout to prevent label cutoff
plt.tight_layout()

# Save the plot
plt.savefig('./automated_underwater_area_estimation/evaluation_results_vm/coralscop_train/comparison/model_metrics_comparison.png',
            dpi=300, bbox_inches='tight')

# Show the plot
plt.show()

print("Grouped bar chart created successfully!")
print("Chart saved as 'model_metrics_comparison.png'")
# Out:
# Grouped bar chart created successfully!
# Chart saved as 'model_metrics_comparison.png'
